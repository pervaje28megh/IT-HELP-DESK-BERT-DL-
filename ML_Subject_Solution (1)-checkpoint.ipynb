# %%
import warnings
#to suppress the warnings
warnings.filterwarnings("ignore")
import pandas as pd
main_df = pd.read_csv('/content/drive/MyDrive/df_withoutdup_final_orig.csv',encoding='windows-1252')

# Adding a column in the dataframe which concatenates the review's title and body.
main_df_new = pd.DataFrame()
main_df_new["combined data"] = "-"
main_df_new["combined data"] = main_df["Subject"] + " " + main_df["Message"]
main_df_new.head()
main_df_new.shape
# Out:
# (8040, 1)

# %% [markdown]
# Data pre-Processing

# %% [markdown]
# Installing required libraries for preprocessing of the data

# %%
# !pip install contractions
# !pip install nltk
# !pip install autocorrect
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting contractions
#   Downloading contractions-0.1.72-py2.py3-none-any.whl (8.3 kB)
# Collecting textsearch>=0.0.21
#   Downloading textsearch-0.0.21-py2.py3-none-any.whl (7.5 kB)
# Collecting pyahocorasick
#   Downloading pyahocorasick-1.4.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      |████████████████████████████████| 106 kB 6.9 MB/s
# Collecting anyascii
#   Downloading anyascii-0.3.1-py3-none-any.whl (287 kB)
#      |████████████████████████████████| 287 kB 50.3 MB/s
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.1 contractions-0.1.72 pyahocorasick-1.4.4 textsearch-0.0.21
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.64.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting autocorrect
#   Downloading autocorrect-2.6.1.tar.gz (622 kB)
#      |████████████████████████████████| 622 kB 7.7 MB/s
# Building wheels for collected packages: autocorrect
#   Building wheel for autocorrect (setup.py) ... done
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622382 sha256=adb44ab9210a23a5d39b8853944ccd91fd44fc1308e741c2741f382acd596e46
#   Stored in directory: /root/.cache/pip/wheels/54/d4/37/8244101ad50b0f7d9bffd93ce58ed7991ee1753b290923934b
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-2.6.1

# %%
import string
import nltk
import re
from nltk.stem import WordNetLemmatizer
from string import punctuation
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
#Function to split a paragraph into sentences.
def sent_tokens_func(text):
  return nltk.sent_tokenize(text)

#Function to split a given sentence into words.
def word_tokens_func(text):
  return nltk.word_tokenize(text)  

#Function to convert the text into Lowercase letters
def to_lower(text):
  if not isinstance(text,str):
    text = str(text)
  return text.lower()

#Function to omit the numbers from the text
def number_omit_func(text):
  output = ''.join(c for c in text if not c.isdigit())
  return output

#Function to omit the punctuation marks from the text
def remove_punctuation(text):
  return ''.join(c for c in text if c not in punctuation) 

#Function to remove the stopwords from the given text using nltk
def stopword_remove_func(sentence):
  stop_words = stopwords.words('english')
  return ' '.join([w for w in nltk.word_tokenize(sentence) if not w in stop_words])

# %%
#Function to perform lemmatization for the text using WordNet Lemmatizer
def lemmatize(text):
          wordnet_lemmatizer = WordNetLemmatizer()
          lemmatized_word = [wordnet_lemmatizer.lemmatize(word)for word in nltk.word_tokenize(text)]
          return " ".join(lemmatized_word)

# Function to call other sub functions such as number_omit,remove_punctuation etc.,
def preprocess(text):
        lower_text = to_lower(text)
        sentence_tokens = sent_tokens_func(lower_text)
        word_list = []
        for each_sent in sentence_tokens:
            lemmatizzed_sent = lemmatize(each_sent)
            clean_text = number_omit_func(lemmatizzed_sent)
            clean_text = remove_punctuation(clean_text)
            clean_text = stopword_remove_func(clean_text)
            word_tokens = word_tokens_func(clean_text)
            for i in word_tokens:
                word_list.append(i)
        return " ".join(word_list)

# %%
sample_data = main_df_new['combined data']
sample_data = sample_data.apply(preprocess)
main_df_new['preprocessed combined data'] = sample_data

# %%
main_df_new.head(5)
# Out:
#                                        combined data  \
# 0  Not able to receive the files through Pinmaile...
# 1   FTP setup in mac system FTP setup in mac system.
# 2  Data not received through SFTP Dear Sir,    Da...
# 3  Sftp Client installation Need to install SFTP ...
# 4  Require Dataprep SFTP and Bluedart site Blue d...
#
#                           preprocessed combined data
# 0  able receive file pinmailer sftp able receive ...
# 1          ftp setup mac system ftp setup mac system
# 2  data received sftp dear sir data received sftp...
# 3  sftp client installation need install sftp cli...
# 4  require dataprep sftp bluedart site blue dart ...

# %%
main_df_new.to_csv("Preprocessed_data.csv",index=False)
main_df_new.head()
# Out:
#                                        combined data  \
# 0  Not able to receive the files through Pinmaile...
# 1   FTP setup in mac system FTP setup in mac system.
# 2  Data not received through SFTP Dear Sir,    Da...
# 3  Sftp Client installation Need to install SFTP ...
# 4  Require Dataprep SFTP and Bluedart site Blue d...
#
#                           preprocessed combined data
# 0  able receive file pinmailer sftp able receive ...
# 1          ftp setup mac system ftp setup mac system
# 2  data received sftp dear sir data received sftp...
# 3  sftp client installation need install sftp cli...
# 4  require dataprep sftp bluedart site blue dart ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_all_rows = pd.concat([main_df,main_df_new],axis=1)
df_all_rows
# Out:
#       Unnamed: 0  Sl.No  RefNumber               Name  \
# 0              0     37      25152        Shashanka P
# 1              1     58      25175             Umesha
# 2              2     81      25199        Shashanka P
# 3              3    224      25374        Reshma Bhat
# 4              4    593      25904        Reshma Bhat
# ...          ...    ...        ...                ...
# 8035        9486   8796      42106       Glan Menezes
# 8036        9487   8892      42311  Shashidhar Shetty
# 8037        9488   8911      42362   Nilesh S Acharya
# 8038        9489   9373      43323             Nithin
# 8039        9490   9481      43550     Shrutha Thejas
#
#                                                 Subject  Priority  \
# 0     Not able to receive the files through Pinmaile...       Low
# 1                               FTP setup in mac system       Low
# 2                        Data not received through SFTP      High
# 3                              Sftp Client installation    Medium
# 4               Require Dataprep SFTP and Bluedart site    Medium
# ...                                                 ...       ...
# 8035     System Hanging & Slow - System OS up gradation       Low
# 8036  MY WFH LAPTOP SLOW PROCESSING AND HANGING WHIL...       Low
# 8037      Unit-9 Vault PC is very slow and getting hang       Low
# 8038                    system hanging not able to work  Critical
# 8039     Laptop hangs frequently and interrupts working      High
#
#              AssaignedName                EntryDate            eng_exit_date  \
# 0     Jackson Dale Bangera  2020-07-01 15:18:40.223  2020-07-02 17:43:32.403
# 1           Poornesh Kumar  2020-07-02 14:49:29.920  2020-07-02 15:16:43.657
# 2               Jeevandas   2020-07-03 10:40:24.793  2020-07-03 12:03:10.467
# 3                 Sowmya P  2020-07-10 11:36:51.890  2020-07-10 14:45:04.467
# 4         Sudarshan Mallya  2020-07-29 14:08:58.907  2020-07-30 12:24:53.467
# ...                    ...                      ...                      ...
# 8035              Prajwal   2022-04-30 11:49:27.397  2022-05-30 17:53:30.473
# 8036       Manikanta Nayak  2022-05-10 15:13:51.983  2022-05-25 16:37:42.333
# 8037            Jeevandas   2022-05-12 10:11:47.300  2022-06-22 15:24:49.540
# 8038        Sachin J Nayak  2022-06-20 12:12:44.817  2022-06-20 15:49:19.923
# 8039       Manikanta Nayak                  14:15.4                      NaN
#
#                     restotal  ... COMPLAINT CATEGORY  \
# 0      1 Days 2 hrs 25 mins   ...                 IT
# 1      0 Days 1 hrs 27 mins   ...                 IT
# 2      0 Days 2 hrs 23 mins   ...                 IT
# 3       0 Days 3 hrs 9 mins   ...                 IT
# 4     1 Days 22 hrs 16 mins   ...                 IT
# ...                      ...  ...                ...
# 8035   30 Days 6 hrs 4 mins   ...                 IT
# 8036  15 Days 1 hrs 24 mins   ...                 IT
# 8037  41 Days 5 hrs 13 mins   ...                 IT
# 8038   0 Days 3 hrs 37 mins   ...                 IT
# 8039                     NaN  ...                 IT
#
#      COMPLAINT REQUEST CATEGORY COMPLAINT REQUEST TYPE  \
# 0                      Incident         Network Issues
# 1                      Incident                 Others
# 2                      Incident         Network Issues
# 3                       Service            Site access
# 4                       Service            Site access
# ...                         ...                    ...
# 8035                   Incident    System/Laptop Issue
# 8036                    Service                 Others
# 8037                    Service                 Others
# 8038                   Incident    System/Laptop Issue
# 8039                   Incident    System/Laptop Issue
#
#              COMPLAINT DETAILS CUSTOMER IMPACT  \
# 0          Share folder issues              no
# 1                       Others              no
# 2     Network Connection Issue              no
# 3                          NaN              no
# 4                          NaN              no
# ...                        ...             ...
# 8035            System is Slow              no
# 8036                       NaN             yes
# 8037                       NaN              no
# 8038               System down              no
# 8039            System is Slow             yes
#
#                                                 Message  \
# 0     Not able to receive the files through Pinmaile...
# 1                              FTP setup in mac system.
# 2     Dear Sir,    Data not received through SFTP at...
# 3     Need to install SFTP client to access MCT Prep...
# 4     Blue dart Site is not accessing.  Require Data...
# ...                                                 ...
# 8035                              System Slow & hanging
# 8036  MY WFH LAPTOP SLOW PROCESSING AND HANGING WHIL...
# 8037  Hi IT Team,    Please note our Unit-9 Vault PC...
# 8038                    system hanging not able to work
# 8039  Laptop hangs very frequently and it causes int...
#
#                                                Solution Ratings  \
# 0     Please follow below steps.\n1. Download SSHLic...     NaN
# 1     From the Apple menu, select System Preferences...     NaN
# 2     Please follow below steps.\n1. Download SSHLic...     NaN
# 3     Follow the link given https://www.webservertal...     4.0
# 4     You can create a SFTP connection through the T...     5.0
# ...                                                 ...     ...
# 8035  Install all recommended updates for Windows us...     5.0
# 8036  Install The Latest Windows Updates.\nUpgrade R...     5.0
# 8037  Use A Cooling Pad To Prevent Laptop Overheatin...     5.0
# 8038  Check for updated firmware and drivers from PC...     NaN
# 8039  Close Unwanted Apps & Services Running In The ...     NaN
#
#                                           combined data  \
# 0     Not able to receive the files through Pinmaile...
# 1      FTP setup in mac system FTP setup in mac system.
# 2     Data not received through SFTP Dear Sir,    Da...
# 3     Sftp Client installation Need to install SFTP ...
# 4     Require Dataprep SFTP and Bluedart site Blue d...
# ...                                                 ...
# 8035  System Hanging & Slow - System OS up gradation...
# 8036  MY WFH LAPTOP SLOW PROCESSING AND HANGING WHIL...
# 8037  Unit-9 Vault PC is very slow and getting hang ...
# 8038  system hanging not able to work system hanging...
# 8039  Laptop hangs frequently and interrupts working...
#
#                              preprocessed combined data
# 0     able receive file pinmailer sftp able receive ...
# 1             ftp setup mac system ftp setup mac system
# 2     data received sftp dear sir data received sftp...
# 3     sftp client installation need install sftp cli...
# 4     require dataprep sftp bluedart site blue dart ...
# ...                                                 ...
# 8035  system hanging slow system gradation system sl...
# 8036  wfh laptop slow processing hanging multitaskin...
# 8037  unit vault pc slow getting hang hi team please...
# 8038  system hanging able work system hanging able work
# 8039  laptop hang frequently interrupt working lapto...
#
# [8040 rows x 29 columns]
